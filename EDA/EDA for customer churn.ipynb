# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
df=pd.read_csv("Customer_Churn.csv")
df.head()
# Out:
#    Unnamed: 0  RowNumber  CustomerId   Surname  CreditScore Geography  Gender  \
# 0           0          1    15634602  Hargrave          619    France  Female
# 1           1          2    15647311      Hill          608     Spain  Female
# 2           2          3    15619304      Onio          502    France  Female
# 3           3          4    15701354      Boni          699    France  Female
# 4           4          5    15737888  Mitchell          850     Spain  Female
#
#    Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0   42       2       0.00              1          1               1
# 1   41       1   83807.86              1          0               1
# 2   42       8  159660.80              3          1               0
# 3   39       1       0.00              2          0               0
# 4   43       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited     Churn
# 0        101348.88       1  0.273976
# 1        112542.58       0  0.002195
# 2        113931.57       1  0.999994
# 3         93826.63       0  0.011650
# 4         79084.10       0  0.012742

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull(),cbar=False,yticklabels=False)
df.isna().sum()
# Out:
# Unnamed: 0         0
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# Churn              0
# dtype: int64

# %%
# sns.countplot(x="Exited",data=df,hue="EstimatedSalary")

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x="Geography",y="EstimatedSalary",data=df)
# Out:
# <AxesSubplot:xlabel='Geography', ylabel='EstimatedSalary'>

# %%
sns.pairplot(data=df)

# %%
sns.distplot(df["Age"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-cf0334540b62> in <module>
# ----> 1 sns.distplot(df["Age"])
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     215         orientation = "horizontal" if vertical else "vertical"
#     216         hist_color = hist_kws.pop("color", color)
# --> 217         ax.hist(a, bins, orientation=orientation,
#     218                 color=hist_color, **hist_kws)
#     219         if hist_color != color:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6818             if patch:
#    6819                 p = patch[0]
# -> 6820                 p.update(kwargs)
#    6821                 if lbl is not None:
#    6822                     p.set_label(lbl)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'normed'
